# %% [markdown]
# https://medium.com/ai-techsystems/fruits-classification-using-deep-learning-f8261b0ee0ca

# %% [markdown]
# https://www.sciencedirect.com/science/article/pii/S0168169923003782#:~:text=Fruit%20Classification%20Model%20using%20Deep,intensity%2C%20and%2C%20texture%20form.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip   /content/drive/MyDrive/LSBU/Deep Learning/Deep Learning Model/dataset/rottentomato.zip
# Out:
# unzip:  cannot find or open /content/drive/MyDrive/LSBU/Deep, /content/drive/MyDrive/LSBU/Deep.zip or /content/drive/MyDrive/LSBU/Deep.ZIP.

# %%
import zipfile
import os

# Path to the zip file
zip_file_path = "/content/drive/MyDrive/LSBU/Deep Learning/Deep Learning Model/dataset/output.zip"

# Destination folder for extraction
extracted_folder_path = '/content/'
# Create the destination folder if it doesn't exist
os.makedirs(extracted_folder_path, exist_ok=True)

# Open the zip file
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    # Extract all contents to the destination folder
    zip_ref.extractall(extracted_folder_path)

# List the contents of the extracted folder
extracted_contents = os.listdir(extracted_folder_path)
print("Extracted contents:", extracted_contents)
# Out:
# Extracted contents: ['.config', 'Train', 'Test', 'drive', 'sample_data']

# %%
import os
import random

# Specify the directory containing the images
directory = '/content/Train/rottenapples'

# List all the files in the directory
all_files = os.listdir(directory)

# Randomly select and delete 300 files
for _ in range(250):
    file_to_delete = random.choice(all_files)
    file_path = os.path.join(directory, file_to_delete)
    try:
        os.remove(file_path)
        print(f"Deleted: {file_path}")
    except Exception as e:
        print(f"Failed to delete: {file_path}, Error: {e}")
# Out:
# Deleted: /content/Train/rottenapples/saltandpepper_Screen Shot 2018-06-07 at 3.03.31 PM.png
# Deleted: /content/Train/rottenapples/a_r839.png
# Deleted: /content/Train/rottenapples/rotated_by_15_Screen Shot 2018-06-08 at 2.50.55 PM.png
# Deleted: /content/Train/rottenapples/rotated_by_60_Screen Shot 2018-06-07 at 2.34.36 PM.png
# Deleted: /content/Train/rottenapples/a_r191.png
# Deleted: /content/Train/rottenapples/a_r551.png
# Deleted: /content/Train/rottenapples/rotated_by_45_Screen Shot 2018-06-08 at 2.51.43 PM.png
# Deleted: /content/Train/rottenapples/translation_Screen Shot 2018-06-07 at 2.24.59 PM.png
# Deleted: /content/Train/rottenapples/rotated_by_15_Screen Shot 2018-06-07 at 2.51.37 PM.png
# Deleted: /content/Train/rottenapples/a_r719.png
# Deleted: /content/Train/rottenapples/vertical_flip_Screen Shot 2018-06-08 at 2.50.49 PM.png
# Deleted: /content/Train/rottenapples/a_r698.png
# Deleted: /content/Train/rottenapples/rotated_by_75_Screen Shot 2018-06-07 at 2.43.48 PM.png
# ...

# %%
import os
import random

# Specify the directory containing the images
directory = '/content/Train/rottenpotato'

# List all the files in the directory
all_files = os.listdir(directory)

# Randomly select and delete 300 files
for _ in range(600):
    file_to_delete = random.choice(all_files)
    file_path = os.path.join(directory, file_to_delete)
    try:
        os.remove(file_path)
        print(f"Deleted: {file_path}")
    except Exception as e:
        print(f"Failed to delete: {file_path}, Error: {e}")
# Out:
# Deleted: /content/Train/rottenpotato/p_r542_0_7328.jpeg
# Deleted: /content/Train/rottenpotato/p_r104_0_9695.jpeg
# Deleted: /content/Train/rottenpotato/p_r665_0_2224.jpeg
# Deleted: /content/Train/rottenpotato/p_r622_0_9565.jpeg
# Deleted: /content/Train/rottenpotato/p_r174_0_9810.jpeg
# Deleted: /content/Train/rottenpotato/p_r167_0_7322.jpeg
# Deleted: /content/Train/rottenpotato/p_r373_0_9712.jpeg
# Deleted: /content/Train/rottenpotato/p_r689_0_1117.jpeg
# Deleted: /content/Train/rottenpotato/p_r313_0_9234.jpeg
# Deleted: /content/Train/rottenpotato/p_r707_0_3633.jpeg
# Deleted: /content/Train/rottenpotato/p_r604_0_7981.jpeg
# Deleted: /content/Train/rottenpotato/p_r024_0_8719.jpeg
# Deleted: /content/Train/rottenpotato/p_r244_0_5590.jpeg
# Deleted: /content/Train/rottenpotato/p_r542_0_155.jpeg
# Deleted: /content/Train/rottenpotato/p_r749_0_3882.jpeg
# Deleted: /content/Train/rottenpotato/p_r417_0_7319.jpeg
# Deleted: /content/Train/rottenpotato/p_r155_0_8319.jpeg
# ...

# %%
import os
import random

# Specify the directory containing the images
directory = '/content/Train/freshokra'

# List all the files in the directory
all_files = os.listdir(directory)

# Randomly select and delete 300 files
for _ in range(600):
    file_to_delete = random.choice(all_files)
    file_path = os.path.join(directory, file_to_delete)
    try:
        os.remove(file_path)
        print(f"Deleted: {file_path}")
    except Exception as e:
        print(f"Failed to delete: {file_path}, Error: {e}")
# Out:
# Deleted: /content/Train/freshokra/o_f433_0_9451.jpeg
# Deleted: /content/Train/freshokra/o_f069_0_4698.jpeg
# Deleted: /content/Train/freshokra/o_f248_0_3865.jpeg
# Deleted: /content/Train/freshokra/o_f507_0_3659.jpeg
# Deleted: /content/Train/freshokra/o_f184_0_9430.jpeg
# Deleted: /content/Train/freshokra/o_f581_0_4699.jpeg
# Deleted: /content/Train/freshokra/o_f206_0_8025.jpeg
# Deleted: /content/Train/freshokra/o_f059_0_5118.jpeg
# Deleted: /content/Train/freshokra/o_f612_0_5492.jpeg
# Deleted: /content/Train/freshokra/o_f299_0_9269.jpeg
# Deleted: /content/Train/freshokra/o_f092_0_975.jpeg
# Deleted: /content/Train/freshokra/o_f583_0_2205.jpeg
# Deleted: /content/Train/freshokra/o_f622_0_6796.jpeg
# Deleted: /content/Train/freshokra/o_f315_0_1261.jpeg
# Deleted: /content/Train/freshokra/o_f499_0_8024.jpeg
# Deleted: /content/Train/freshokra/o_f515_0_9652.jpeg
# Deleted: /content/Train/freshokra/o_f589_0_7946.jpeg
# Deleted: /content/Train/freshokra/o_f198_0_6414.jpeg
# ...

# %%
import os
import random

# Specify the directory containing the images
directory = '/content/Train/freshpotato'

# List all the files in the directory
all_files = os.listdir(directory)

# Randomly select and delete 300 files
for _ in range(220):
    file_to_delete = random.choice(all_files)
    file_path = os.path.join(directory, file_to_delete)
    try:
        os.remove(file_path)
        print(f"Deleted: {file_path}")
    except Exception as e:
        print(f"Failed to delete: {file_path}, Error: {e}")
# Out:
# Deleted: /content/Train/freshpotato/p_f223_0_7543.jpeg
# Deleted: /content/Train/freshpotato/p_f404_0_2782.jpeg
# Deleted: /content/Train/freshpotato/p_f199_0_3960.jpeg
# Deleted: /content/Train/freshpotato/p_f337_0_3738.jpeg
# Deleted: /content/Train/freshpotato/p_f322_0_661.jpeg
# Deleted: /content/Train/freshpotato/p_f107_0_5750.jpeg
# Deleted: /content/Train/freshpotato/p_f110_0_2277.jpeg
# Deleted: /content/Train/freshpotato/p_f151_0_1264.jpeg
# Deleted: /content/Train/freshpotato/p_f213_0_790.jpeg
# Deleted: /content/Train/freshpotato/p_f011_0_763.jpeg
# Deleted: /content/Train/freshpotato/p_f049_0_5664.jpeg
# Deleted: /content/Train/freshpotato/p_f375_0_2458.jpeg
# Deleted: /content/Train/freshpotato/p_f171_0_104.jpeg
# Deleted: /content/Train/freshpotato/p_f526_0_2139.jpeg
# Deleted: /content/Train/freshpotato/p_f041_0_5799.jpeg
# Deleted: /content/Train/freshpotato/p_f342_0_4931.jpeg
# Deleted: /content/Train/freshpotato/p_f498_0_7964.jpeg
# ...

# %%
# Import necessary libraries
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical

# Set the path to your dataset
train_data_dir = '/content/Train'
test_data_dir = '/content/Test'

# %%
img_size = (150, 150)
batch_size = 32

# Use ImageDataGenerator for data augmentation
train_datagen = ImageDataGenerator(
        validation_split=0.2,
        rotation_range=20,
        width_shift_range=0.2,
        height_shift_range=0.2,
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True,
        fill_mode='nearest'
)

test_datagen = ImageDataGenerator(rescale=1./255)

# Load and preprocess the training dataset
train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=True,
    seed=10,
    subset="training"
)

# Load and preprocess the test dataset
test_generator = test_datagen.flow_from_directory(
    test_data_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)
val_data_generator = ImageDataGenerator(rescale=1./255, validation_split=0.2)
# Generator para parte validação
validation_generator = val_data_generator.flow_from_directory(train_data_dir, target_size=img_size, shuffle=False, seed=10,
                                                     class_mode='categorical', batch_size=batch_size, subset="validation")
# Out:
# Found 19805 images belonging to 14 classes.
# Found 6738 images belonging to 14 classes.
# Found 4944 images belonging to 14 classes.

# %%
total_images = 21017 + 6738 + 5246  # Total number of images

train_percentage = (21017 / total_images) * 100
test_percentage = (6738 / total_images) * 100
validation_percentage = (5246 / total_images) * 100

print(f"Train Percentage: {train_percentage:.2f}%")
print(f"Test Percentage: {test_percentage:.2f}%")
print(f"Validation Percentage: {validation_percentage:.2f}%")
# Out:
# Train Percentage: 63.69%
# Test Percentage: 20.42%
# Validation Percentage: 15.90%

# %%
import os

# Specify the directory path
directory_path = '/content/Train/freshokra'

# Get the list of files in the directory
files = os.listdir(directory_path)

# Get the count of files
file_count = len(files)

print(f'The number of files in the directory is: {file_count}')
# Out:
# The number of files in the directory is: 1998

# %%
import numpy as np

# Get the count of images belonging to each class
class_counts = train_generator.classes
unique_classes, counts = np.unique(class_counts, return_counts=True)

# Display the count for each class
for class_index, count in zip(unique_classes, counts):
    print(f"Class {class_index}: {count} images")
    class_count_list = []
    class_count_list.append(count)
# Out:
# Class 0: 1140 images
# Class 1: 1175 images
# Class 2: 1588 images
# Class 3: 1599 images
# Class 4: 1173 images
# Class 5: 1551 images
# Class 6: 1487 images
# Class 7: 1606 images
# Class 8: 1546 images
# Class 9: 1348 images
# Class 10: 1352 images
# Class 11: 1276 images
# Class 12: 1504 images
# Class 13: 1460 images

# %%
count_list=list(counts)
classes = ["freshapples", "fresh Banana", "fresh cucumber", "fresh okra", "fresh orange","fresh potato","fresh tomato","rotten apple","rotten banana","rotten cucumber","rotten okra","rotten oranges","rotten potato","rotten tomato"]

# %%
count_list
# Out:
# [1140,
#  1175,
#  1588,
#  1599,
#  1173,
#  1551,
#  1487,
#  1606,
#  1546,
#  1348,
#  1352,
#  1276,
#  1504,
#  1460]

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# Create a DataFrame from the data
data = pd.DataFrame({"Classes": classes, "Values": count_list})

# Create a bar chart using Seaborn
plt.figure(figsize=(10, 6))  # Optional: Adjust the figure size
sns.barplot(x="Values", y="Classes", data=data, palette="viridis")

# Optional: Add labels and a title
plt.xlabel("Values")
plt.ylabel("Classes")
plt.title("Bar Chart of Classes vs. Values")

# Show the chart
plt.show()

# %%
from tensorflow.keras import models, layers

model = models.Sequential()

# First convolutional layer with Batch Normalization and Leaky ReLU activation
model.add(layers.Conv2D(32, (3, 3), input_shape=(150, 150, 3)))
model.add(layers.BatchNormalization())
model.add(layers.LeakyReLU(alpha=0.1))
model.add(layers.MaxPooling2D((2, 2)))

# Second convolutional layer with Batch Normalization and Leaky ReLU activation
model.add(layers.Conv2D(64, (3, 3)))
model.add(layers.BatchNormalization())
model.add(layers.LeakyReLU(alpha=0.1))
model.add(layers.MaxPooling2D((2, 2)))

# Third convolutional layer with Batch Normalization and Leaky ReLU activation
model.add(layers.Conv2D(128, (3, 3)))
model.add(layers.BatchNormalization())
model.add(layers.LeakyReLU(alpha=0.1))
model.add(layers.MaxPooling2D((2, 2)))

# Additional convolutional layer with Batch Normalization and Leaky ReLU activation
model.add(layers.Conv2D(256, (3, 3)))
model.add(layers.BatchNormalization())
model.add(layers.LeakyReLU(alpha=0.1))
model.add(layers.MaxPooling2D((2, 2)))

# Flatten layer to transition from convolutional layers to dense layers
model.add(layers.Flatten())

# Dense layers with Batch Normalization and Leaky ReLU activation
model.add(layers.Dense(256))
model.add(layers.BatchNormalization())
model.add(layers.LeakyReLU(alpha=0.1))
model.add(layers.Dropout(0.5))

model.add(layers.Dense(128))
model.add(layers.BatchNormalization())
model.add(layers.LeakyReLU(alpha=0.1))

# Output layer with 14 classes and softmax activation
model.add(layers.Dense(14, activation='softmax'))

# Compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Print the model summary to see the architecture
model.summary()

# Train the model with adjusted batch size
history = model.fit(train_generator, epochs=30, validation_data=validation_generator, batch_size=32)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_4 (Conv2D)           (None, 148, 148, 32)      896
#
#  batch_normalization_6 (Bat  (None, 148, 148, 32)      128
#  chNormalization)
#
#  leaky_re_lu_6 (LeakyReLU)   (None, 148, 148, 32)      0
#
#  max_pooling2d_4 (MaxPoolin  (None, 74, 74, 32)        0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 72, 72, 64)        18496
#
#  batch_normalization_7 (Bat  (None, 72, 72, 64)        256
#  chNormalization)
#
#  leaky_re_lu_7 (LeakyReLU)   (None, 72, 72, 64)        0
#
#  max_pooling2d_5 (MaxPoolin  (None, 36, 36, 64)        0
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 34, 34, 128)       73856
#
#  batch_normalization_8 (Bat  (None, 34, 34, 128)       512
#  chNormalization)
#
#  leaky_re_lu_8 (LeakyReLU)   (None, 34, 34, 128)       0
#
#  max_pooling2d_6 (MaxPoolin  (None, 17, 17, 128)       0
#  g2D)
#
# ...

# %%
# # Build the CNN model
# model = models.Sequential()
# model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(150, 150, 3)))
# model.add(layers.MaxPooling2D((2, 2)))
# model.add(layers.Conv2D(64, (3, 3), activation='relu'))
# model.add(layers.MaxPooling2D((2, 2)))
# model.add(layers.Conv2D(128, (3, 3), activation='relu'))
# model.add(layers.MaxPooling2D((2, 2)))
# model.add(layers.Flatten())
# model.add(layers.Dense(128, activation='relu'))
# model.add(layers.Dense(14, activation='softmax'))  # Output layer with 14 classes

# # Compile the model
# model.compile(optimizer='adam',
#               loss='categorical_crossentropy',
#               metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 148, 148, 32)      896
#
#  max_pooling2d (MaxPooling2  (None, 74, 74, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 72, 72, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 36, 36, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 34, 34, 128)       73856
#
#  max_pooling2d_2 (MaxPoolin  (None, 17, 17, 128)       0
#  g2D)
#
#  flatten (Flatten)           (None, 36992)             0
#
#  dense (Dense)               (None, 128)               4735104
#
#  dense_1 (Dense)             (None, 14)                1806
#
# ...
# Total params: 4830158 (18.43 MB)
# Trainable params: 4830158 (18.43 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Train the model
history = model.fit(train_generator, epochs=25, validation_data=validation_generator)
# Out:
# Epoch 1/25
# 619/619 [==============================] - 223s 344ms/step - loss: 1.4438 - accuracy: 0.4569 - val_loss: 1.1914 - val_accuracy: 0.5772
# Epoch 2/25
# 619/619 [==============================] - 187s 301ms/step - loss: 0.8969 - accuracy: 0.6349 - val_loss: 0.9287 - val_accuracy: 0.6397
# Epoch 3/25
# 619/619 [==============================] - 186s 301ms/step - loss: 0.7563 - accuracy: 0.6904 - val_loss: 0.8137 - val_accuracy: 0.6478
# Epoch 4/25
# 619/619 [==============================] - 187s 302ms/step - loss: 0.6683 - accuracy: 0.7269 - val_loss: 0.7455 - val_accuracy: 0.7276
# Epoch 5/25
# 619/619 [==============================] - 185s 299ms/step - loss: 0.5970 - accuracy: 0.7641 - val_loss: 0.7320 - val_accuracy: 0.6825
# Epoch 6/25
# 619/619 [==============================] - 184s 298ms/step - loss: 0.5443 - accuracy: 0.7845 - val_loss: 0.8974 - val_accuracy: 0.7045
# Epoch 7/25
# ...

# %%
# Evaluate the model on the test set
test_loss, test_acc = model.evaluate(test_generator)
print(f'Test accuracy: {test_acc}')
# Out:
# 211/211 [==============================] - 31s 145ms/step - loss: 0.4667 - accuracy: 0.8756
# Test accuracy: 0.8756307363510132

# %%
model.save('final fruit_classification 1.h5')

# %%
# Evaluate the model on the train set
train_eval = model.evaluate(train_generator, verbose=1)
print(f'Train Accuracy: {train_eval[1]*100:.2f}%')

# Evaluate the model on the test set
test_eval = model.evaluate(test_generator, verbose=1)
print(f'Test Accuracy: {test_eval[1]*100:.2f}%')
# Out:
# 619/619 [==============================] - 175s 283ms/step - loss: 0.2443 - accuracy: 0.9155
# Train Accuracy: 91.55%
# 211/211 [==============================] - 29s 136ms/step - loss: 0.4667 - accuracy: 0.8756
# Test Accuracy: 87.56%

# %%
import matplotlib.pyplot as plt

# Assuming you have already compiled your model and have your training data
# model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])


# Plot training and validation accuracy values
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Plot training and validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# Load and preprocess the training dataset
train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=True,
    seed=10,
    subset="training"
)

# Define class_names
class_names = sorted(train_generator.class_indices.keys())

# Rest of the code...

# Plot confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# Display details of the confusion matrix
report = classification_report(y_true, y_pred_classes, target_names=class_names)
print('Classification Report:\n', report)
# Out:
# Found 19795 images belonging to 14 classes.
# Classification Report:
#                  precision    recall  f1-score   support
#
#    freshapples       0.99      0.92      0.95       791
#    freshbanana       0.97      0.99      0.98       892
#  freshcucumber       0.85      0.90      0.87       279
#      freshokra       0.95      0.79      0.86       370
#   freshoranges       0.94      0.91      0.93       388
#    freshpotato       0.74      0.78      0.76       270
#    freshtomato       0.53      1.00      0.70       255
#   rottenapples       0.92      0.95      0.93       988
#   rottenbanana       0.91      0.96      0.93       900
# rottencucumber       0.74      0.89      0.81       255
#     rottenokra       0.86      0.69      0.76       224
#  rottenoranges       0.81      0.96      0.88       403
#   rottenpotato       0.81      0.59      0.68       370
#   rottentomato       0.94      0.39      0.55       353
#
# ...

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from itertools import cycle

# Convert multiclass labels to binary format
y_true_bin = label_binarize(y_true, classes=np.arange(14))

# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(14):  # Assuming you have 14 classes
    fpr[i], tpr[i], _ = roc_curve(y_true_bin[:, i], y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot ROC curves
plt.figure(figsize=(10, 8))
colors = cycle(['aqua', 'darkorange', 'cornflowerblue', 'red', 'green', 'purple', 'brown', 'pink', 'gray', 'olive', 'cyan', 'lime', 'blue', 'yellow'])
for i, color in zip(range(14), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=2, label=f'Class {i} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()

# %%
import numpy as np
from tensorflow.keras.preprocessing import image

# Load the single test image
img_path = '/content/download.jfif'  # Replace with the path to your image
img = image.load_img(img_path, target_size=(150, 150))

# Convert the image to a numpy array and normalize it
img_array = image.img_to_array(img)
img_array = img_array / 255.0

# Add an extra dimension to match the model's expected input shape
img_array = np.expand_dims(img_array, axis=0)

# Make predictions
predictions = model.predict(img_array)

# Get the class index with the highest probability
predicted_class_index = np.argmax(predictions[0])

# Print the predicted class
class_names = ['class_1', 'class_2', 'class_3', ...]  # Replace with your class names
#predicted_class = class_names[predicted_class_index]

print(f'The model predicts: {predicted_class_index}')
# Out:
# 1/1 [==============================] - 0s 258ms/step
# The model predicts: 5

# %%
from sklearn.metrics import precision_recall_curve, auc
from sklearn.preprocessing import label_binarize
from itertools import cycle

# Convert multiclass labels to binary format
y_true_bin = label_binarize(y_true, classes=np.arange(14))

# Compute precision-recall pairs for each class
precision = dict()
recall = dict()
pr_auc = dict()

for i in range(14):  # Assuming you have 14 classes
    precision[i], recall[i], _ = precision_recall_curve(y_true_bin[:, i], y_pred[:, i])
    pr_auc[i] = auc(recall[i], precision[i])

# Plot precision-recall curves
plt.figure(figsize=(10, 8))
colors = cycle(['aqua', 'darkorange', 'cornflowerblue', 'red', 'green', 'purple', 'brown', 'pink', 'gray', 'olive', 'cyan', 'lime', 'blue', 'yellow'])
for i, color in zip(range(14), colors):
    plt.plot(recall[i], precision[i], color=color, lw=2, label=f'Class {i} (AUC = {pr_auc[i]:.2f})')

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc="lower left")
plt.show()

# %%
# Define class_names
class_names = sorted(train_generator.class_indices.keys())
# Out:
# ['freshapples',
#  'freshbanana',
#  'freshcucumber',
#  'freshokra',
#  'freshoranges',
#  'freshpotato',
#  'freshtomato',
#  'rottenapples',
#  'rottenbanana',
#  'rottencucumber',
#  'rottenokra',
#  'rottenoranges',
#  'rottenpotato',
#  'rottentomato']
